# %%
# Simulating ARP Protocol

# %%
import socket

# Create server socket
server = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
# Allows immediate reuse of the port after stopping the script
server.setsockopt(socket.SOL_SOCKET, socket.SO_REUSEADDR, 1)
server.bind(("127.0.0.1", 5000))
server.listen(1)

print("Server is running and listening on port 5000...")

# ARP Table Database
arp_table = {
    "165.165.80.80": "6A:08:AA:C2",
    "165.165.79.1": "8A:BC:E3:FA"
}

try:
    while True:
        conn, addr = server.accept()
        print(f"\n[+] Connected to client: {addr}")
        
        # Handle the connected client
        data = conn.recv(1024).decode().strip()
        if data:
            print(f"[*] Received IP lookup request: {data}")
            # Look up the MAC address or return "Not Found"
            mac = arp_table.get(data, "Not Found")
            conn.send((mac + "\n").encode())
            print(f"[->] Sent MAC response: {mac}")
            
        conn.close()
        print(f"[-] Connection with {addr} closed.")
except KeyboardInterrupt:
    print("\nShutting down server.")
finally:
    server.close()
# Out:
# Server is running and listening on port 5000...
#
# [+] Connected to client: ('127.0.0.1', 57398)
# [*] Received IP lookup request: 165.165.80.80
# [->] Sent MAC response: 6A:08:AA:C2
# [-] Connection with ('127.0.0.1', 57398) closed.
