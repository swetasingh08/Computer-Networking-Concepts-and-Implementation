# %%
import socket

HOST = '127.0.0.1'
PORT = 12345

client = socket.socket(socket.AF_INET, socket.SOCK_STREAM)
client.connect((HOST, PORT))

print("Connected to Echo Server")
print("Type a message to send to the server (type 'bye' to quit):")

while True:
    msg = input()

    client.send(msg.encode())

    if msg.lower() == "bye":
        break

    echo = client.recv(1024).decode()
    print("Echo from server:", echo)

client.close()
# Out:
# Connected to Echo Server
# Type a message to send to the server (type 'bye' to quit):
# Echo from server: Hello
# Echo from server: How are you
# Echo from server: I am fine
